// %%
1+1;
// Out:
// int: 2

// %%
import IO;
// Out:
// ok

// %%
println("hola");
// Out:
// hola
// ok

// %%
:set tracing false
// Out:
// ok

// %%
println(1+1);
// Out:
// 2
// ok

// %%
import IO;
// Out:
// ok

// %%
println(2+2);
// Out:
// 4
// ok

// %%
println("Hello")
// Out:
// Hello
// ok

// %%
int fac(int n) {
    if (n <= 0) return 1;
    return fac(n-1) * n;
}
// Out:
// int (int): function(|prompt:///|(0,69,<1,0>,<4,1>))

// %%
fac(6)
// Out:
// int: 720

// %%
int f(int n) = n<=1? 1 : n * fac(n-1);
// Out:
// int (int): function(|prompt:///|(0,38,<1,0>,<1,38>))

// %%
f(6)
// Out:
// int: 720

// %%
int g(int n) = n<=1? 1 : n * g(n-1);
// Out:
// int (int): function(|prompt:///|(0,36,<1,0>,<1,36>))

// %%
g(6)
// Out:
// int: 720

// %%
g(20)
// Out:
// int: 2432902008176640000

// %%
g(100)
// Out:
// int: 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

// %%
iprintln([ i * i | i <- [1..100000]])
// Out:
// [1,4,9,16,25,36,49,64,81,100,121,144,169,196,225,256,289,324,361,400,441,484,529,576,625,676,729,784,841,900,961,1024,1089,1156,1225,1296,1369,1444,1521,1600,1681,1764,1849,1936,2025,2116,2209,2304,2401,2500,2601,2704,2809,2916,3025,3136,3249,3364,3481,3600,3721,3844,3969,4096,4225,4356,4489,4624,4761,4900,5041,5184,5329,5476,5625,5776,5929,6084,6241,6400,6561,6724,6889,7056,7225,7396,7569,7744,7921,8100,8281,8464,8649,8836,9025,9216,9409,9604,9801,10000,10201,10404,10609,10816,11025,11236,11449,11664,11881,12100,12321,12544,12769,12996,13225,13456,13689,13924,14161,14400,14641,14884,15129,15376,15625,15876,16129,16384,16641,16900,17161,17424,17689,17956,18225,18496,18769,19044,19321,19600,19881,20164,20449,20736,21025,21316,21609,21904,22201,22500,22801,23104,23409,23716,24025,24336,24649,24964,25281,25600,25921,26244,26569,26896,27225,27556,27889,28224,28561,28900,29241,29584,29929,30276,30625,30976,31329,31684,32041,32400,32761,33124,33489,33856,34225,34596,34969,35344,35721,3610
// ...

// %%
:set trace false
// Out:
// ok

// %%
"\<pre\>blabla\<\\pre\>"
// Out:
// str: "\<pre\>blabla\<\\pre\>"

// %%
syntax A = "a";
// Out:
// ok

// %%
import ParseTree;
// Out:
// ok

// %%
parse(#A,"a")
// Out:
// A: (A) `a`

// %%
(A) `a`
// Out:
// A: (A) `a`

// %%
syntax A = "if" A "then" A "else" A;
// Out:
// ok

// %%
layout WS = [ ]*;
// Out:
// ok

// %%
(A) `if a then a else a`
// Out:
// |prompt:///|(0,24,<1,0>,<1,24>): Syntax error: concrete syntax fragment
// Advice: |http://tutor.rascal-mpl.org/Errors/Static/SyntaxError/SyntaxError.html|

// %%
syntax A = Id;
// Out:
// ok

// %%
lexical Id = [a-z]+;
// Out:
// ok

// %%
parse(#A, "ifbthencelsed")
// Out:
// |std:///ParseTree.rsc|(13348,964,<407,0>,<442,87>): Ambiguity(|unknown:///|(0,13,<1,0>,<1,13>),"A","ifbthencelsed")
// 	at *** somewhere ***(|std:///ParseTree.rsc|(13348,964,<407,0>,<442,87>))
// 	at parse(|std:///ParseTree.rsc|(14305,5,<442,80>,<442,85>))

// %% [markdown]
// * hello
//     * bye
// * hola

// %%
|http://www.google.com|
// Out:
// loc: |http://www.google.com|
